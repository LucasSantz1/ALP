# %% [markdown]
# # Exercícios para construir programas com ENTRADA, PROCESSAMENTO e SAÍDA

# %% [markdown]
# ### 1. Faça um programa que leia um número, multiplique ele por 2 e apresente o resultado.
#       LEIA numero
#       resultado = numero * 2
#       ESCREVA resultado

# %%
# 1º passo - identificar a(s) entrada(s) - variável número
numero = int(input('Informe um valor: '))
# 2º passo - identificar o processamento/cálculo
resultado = numero * 2
# 3º passo - apresentar a(s) variáveis que foram calculadas
print('O resultado é',resultado)
# Out:
# Informe um valor: 10
# O resultado é 20

# %% [markdown]
# ### 2. Faça um programa que:
# * receba três números inteiros
# * calcule e mostre a soma desses números.

# %%
# 1° passo - entrada de dados/valores
numero1= int(input('Digite o primeiro número: '))
numero2= int(input('Digite o segundo número: '))
numero3= int(input('Digite o terceiro número: '))
# 2º passo - processamento/cálculo
resultado = numero1+ numero2+ numero3

# 3° passo - saída/apresentação de resultado
print('A soma dos números é', resultado)
# Out:
# Digite o primeiro número: 30
# Digite o segundo número: 40
# Digite o terceiro número: 50
# A soma dos números é 120

# %% [markdown]
# ### 3. Faça um programa que receba três notas, calcule e mostre a média aritmética.

# %%
# 1º passo - entrada de dados
nota1=float(input('Forneça o valor da primeira nota: '))
nota2=float(input('Forneça o valor da segunda nota: '))
nota3=float(input('Forneça o valor da terceira nota: '))
# 2º passo - cálculo/processamento
valor= (nota1+nota2+nota3)/3

#3° passo - saída
print ('O Média das 3 notas é', valor)
# Out:
# Forneça o valor da primeira nota: 10
# Forneça o valor da segunda nota: 20
# Forneça o valor da terceira nota: 3
# O Média das 3 notas é 11.0

# %% [markdown]
# ### 4. Faça um programa que:
# * receba o salário de um funcionário
# * calcule e mostre o novo salário, sabendo-se que este sofreu um aumento de 25%.
#
#       LEIA salario
#       novoSalario = salario + (salario * 25 / 100)
#       ESCREVA novoSalario

# %%
salario = float(input('forneça o salário '))
novosalario = salario + (salario * 25 / 100)
print('Seu novo salário é ', novosalario)
# Out:
# forneça o salário 1000
# Seu novo salário é  1250.0

# %% [markdown]
# ### 5. Faça um programa que receba o salário de um funcionário e o percentual de aumento, calcule e mostre o valor do aumento e o novo salário.

# %%
salario=float(input('informe o novo salário: '))
percentual= float(input('informe o percentual'))
aumento= salario * (percentual/100)
novo= salario+aumento
print('o valordo aumento é R$: ', aumento)
print('O novo salário é R$: ', novo )
# Out:
# informe o novo salário: 1000
# informe o percentual40
# o valordo aumento é R$:  400.0
# O novo salário é R$:  1400.0

# %% [markdown]
# ### 6. Faça um programa que receba o salário base de um funcionário, calcule e mostre o salário a receber, sabendo-se que o funcionário tem gratificação de 5% sobre o salário base e **paga imposto** de 7% também sobre o salário base.

# %%
salario = float(input('Cadastre um salário '))
gratificacao = salario * 5 / 100
imposto = salario * 7 / 100
salario_receber = salario + gratificacao - imposto
print('Valor da gratificação R$',gratificacao)
print('Valor do imposto a pagar R$',imposto)
print('O salário a receber é R$',salario_receber)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-daed7ef8f8b0> in <module>
# ----> 1 salario = float(input('Cadastre um salário '))
#       2 gratificacao = salario * 5 / 100
#       3 imposto = salario * 7 / 100
#       4 salario_receber = salario + gratificacao - imposto
#       5 print('Valor da gratificação R$',gratificacao)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### 7. Faça um programa que receba o salário base de um funcionário, calcule e mostre seu salário a receber, sabendo-se que o funcionário tem gratificação de 50,00 sobre o salário base e **paga** imposto que deve ser lido e é aplicado sobre o salário base.
#
#     LEIA salario, perImposto
#     imposto = salario * perImposto / 100
#     salario_a_receber = salario + 50 - imposto
#     ESCREVA salario_a_receber

# %%
salario = float(input('Digite o valor do seu salário: '))
perimposto = float(input('Digite o valor da sua porcentagem de imposto: '))
imposto = salario * perimposto / 100
salario_a_receber = salario + 50 - imposto
print('O seu imposto em dinheiro é R$:',imposto)
print('O seu salário a receber é:',salario_a_receber)
# Out:
# Digite o valor do seu salário: 1000
# Digite o valor da sua porcentagem de imposto: 10
# O seu imposto em dinheiro é R$: 100.0
# O seu salário a receber é: 950.0

# %% [markdown]
# ### 8. Faça um programa que receba o valor de um depósito e o valor da taxa de juros, calcule e mostre o valor do rendimento e o valor total depois do rendimento de um mês.
#     rendimento = deposito * taxa / 100
#     total = deposito + rendimento

# %%
deposito = float(input('Digite o valor do seu depósito:'))
taxa = float(input('Digite o valor da taxa:'))
rendimento = deposito * taxa / 100
total = deposito + rendimento
print('O valor do seu rendimento é de R$:',rendimento)
print('O valor total após o seu depóstio é de R$:',total)
# Out:
# Digite o valor do seu depósito:8000
# Digite o valor da taxa:80
# O valor do seu rendimento é de R$: 6400.0
# O valor total após o seu depóstio é de R$: 14400.0

# %% [markdown]
# ### 9. Faça um programa que calcule e mostre a área de um triângulo. Sabe-se que: Área = (base * altura) / 2.

# %%
base = float(input('Digite o valor da base do triângulo: '))
altura = float(input('Digite o valor da altura do seu triângulo: '))
area = (base * altura) / 2
print('A área do triângulo é:',area)
# Out:
# Digite o valor da base do triângulo: 20
# Digite o valor da altura do seu triângulo: 10
# A área do triângulo é: 100.0

# %% [markdown]
# ### 10. Faça um programa que calcule e mostre a área de um círculo. Sabe-se que:
#     area = pi * raio² ou
#     area = 3.1415 * raio²

# %%
raio = float(input('Digite o valor do raio: '))
area = 3.1415  * raio**2
print('A área do seu círculo é: ',area )
# Out:
# Digite o valor do raio: 5
# A área do seu círculo é:  78.53750000000001

# %% [markdown]
# ### 11. Faça um programa que receba um número, calcule e mostre:
# * O número digitado ao quadrado
# * O número digitado ao cubo
# * A raiz do número digitado
# * A raiz cúbica do número digitado
#
#       LEIA numero
#       quadrado = numero ** 2
#       cubo = numero ** 3
#       raiz_quadrada = numero ** (½) (meio, ou 0.5)
#       raiz_cubica = numero ** (⅓) (um terço, ou 0.33)
#       ESCREVA quadrado, cubo, raiz_quadrada, raiz_cubica
#
#
#       raiz_quadrada = numero ** (1/2) ou
#       raiz_quadrada = numero ** 0.5

# %%
numero = float(input('Digite o seu número'))
quadrado = numero ** 2
cubo = numero ** 3
raiz_quadrada = numero ** (1/2)
raiz_cubica = numero ** (1/3)
print ('O seu número ao quadrado é', quadrado)
print ('O seu número ao cubo é', cubo)
print ('A sua raiz quadrada é', raiz_quadrada)
print ('A sua raiz cubicaa é', raiz_cubica)
# Out:
# Digite o seu número2
# O seu número ao quadrado é 4.0
# O seu número ao cubo é 8.0
# A sua raiz quadrada é 1.4142135623730951
# A sua raiz cubicaa é 1.2599210498948732

# %% [markdown]
# ### 12. Faça um programa que receba dois números, calcule e mostre um elevado ao outro. Use os caracteres **

# %%
numero1 = float(input('Digite seu primero número: '))
numero2 = float(input('Digite seu segundo número: '))
elevado1 = numero1 ** numero2
elevado2 = numero2 ** numero1
print('O seu primeiro numero elevado ao seu segundo número é: ',elevado1)
print('O seu segundo número elevado ao seu primero número é: ', elevado2)
# Out:
# Digite seu primero número: 5
# Digite seu segundo número: 4
# O seu primeiro numero elevado ao seu segundo número é:  625.0
# O seu segundo número elevado ao seu primero número é:  1024.0

# %% [markdown]
# ### 13. Sabe-se que:
#
# * pé = 12 polegadas
# * 1 jarda = 3 pés
# * 1 milha = 1760 jarda
#
# Faça um programa que receba uma medida em pés, faça as conversões a seguir e mostre os resultados.
#
# * Polegadas;
# * Jardas;
# * Milhas.
#
#       LEIA pes
#       polegadas = pes * 12
#       jardas = pes / 3
#       milhas = jardas / 1760
#       ESCREVA polegadas, jardas, milhas

# %%
pes = float(input('Digite sua medida em pés: '))
polegadas = pes * 12
jardas = pes / 3
milhas = jardas / 1760
print('A sua meida em polegadas é: ',polegadas)
print('A sua medida em jardas é: ',jardas)
print('A sua mediada em milhas é: ',milhas)
# Out:
# Digite sua medida em pés: 1000
# A sua meida em polegadas é:  12000.0
# A sua medida em jardas é:  333.3333333333333
# A sua mediada em milhas é:  0.1893939393939394

# %% [markdown]
# ### 14. Faça um programa que receba o ano de nascimento de uma pessoa e o ano atual, calcule e mostre:
# * a idade atual da pessoa;
# * quantos anos ela terá em 2050.

# %%
nascimento = int(input('Digite seu ano de nascimento: '))
idade_atual = 2022 - nascimento
idade_2050 = 2050 - nascimento
print('Sua idade atual é:',idade_atual)
print('Sua idade em 2050 é:',idade_2050)
# Out:
# Digite seu ano de nascimento: 2021
# Sua idade atual é: 1
# Sua idade em 2050 é: 29

# %% [markdown]
# #### 15. O custo ao consumidor de um carro novo é a soma do preço de fábrica com o percentual de lucro do distribuidor e dos impostos aplicados ao preço de fábrica. Faça um programa que receba o preço de fábrica de um veículo, o percentual de lucro do distribuidor e o percentual de impostos, calcule e mostre:
# * o valor correspondente ao lucro do distribuidor;
# * o valor correspondente aos impostos;
# * o preço final do veículo.
#         LEIA preco_fabrica
#         LEIA percentual_lucro_distribuidor
#         LEIA percentual_imposto
#         lucro_distribuidor = preco_fabrica * percentual_lucro_distribuidor / 100
#         valor_imposto = preco_fabrica * percentual_imposto / 100
#         preco_final = preco_fabrica + lucro_distribuidor + valor_imposto
#         ESCREVA lucro_distribuidor
#         ESCREVA valor_imposto
#         ESCREVA preco_final

# %%
preco_fabrica = float(input('Digite o seu valor de preço de fabrica do seu veículo: '))
percentual_lucro_distribuidor = float(input('Digite o percentual de lucro do distribuidor: '))
percentual_imposto = float(input('Digite o percentual de imposto aplicado: '))
lucro_distribuidor = preco_fabrica * percentual_lucro_distribuidor / 100
valor_imposto = preco_fabrica * percentual_imposto / 100
preco_final = preco_fabrica + lucro_distribuidor + valor_imposto
print('O lucro do distribuidor é:',lucro_distribuidor)
print('O valor do imposto aplicado é:',valor_imposto)
print('O valor final do seu veículo é:',preco_final)
# Out:
# Digite o seu valor de preço de fabrica do seu veículo: 30000
# Digite o percentual de lucro do distribuidor: 50
# Digite o percentual de imposto aplicado: 20
# O lucro do distribuidor é: 15000.0
# O valor do imposto aplicado é: 6000.0
# O valor final do seu veículo é: 51000.0

# %% [markdown]
# ### 16. Faça um programa que receba o número de horas trabalhadas e o valor do salário mínimo, calcule e mostre o salário a receber, seguindo estas regras:
# * a hora trabalhada vale a metade do salário mínimo.
# * o salário bruto equivale ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
# * o imposto equivale a 3% do salário bruto.
# * o salário a receber equivale ao salário bruto menos o imposto.
#       LEIA qtde_horas_trabalhadas
#       LEIA valor_salario_minimo
#       valor_hora_trabalhada = valor_salario_minimo / 2
#       valor_salario_bruto = valor_hora_trabalhada * qtde_horas_trabalhadas
#       imposto = valor_salario_bruto * 3 / 100
#       valor_salario_liquido =  valor_salario_bruto - imposto
#       ESCREVA valor_salario_liquido

# %%
qtde_horas_trabalhadas = float(input('Digite as horas trabalhadas: '))
valor_salario_minimo = float(input('Digite o valor exato do salaário mínimo: '))
valor_hora_trabalhada = valor_salario_minimo / 2
valor_salario_bruto = valor_hora_trabalhada * qtde_horas_trabalhadas
imposto = valor_salario_bruto * 3 / 100
valor_salario_liquido =  valor_salario_bruto - imposto
print('O valor do seu salário liquido é:',valor_salario_liquido)
# Out:
# Digite as horas trabalhadas: 200
# Digite o valor exato do salaário mínimo: 1212
# O valor do seu salário liquido é: 117564.0

# %% [markdown]
# ### 17. Um trabalhador recebeu seu salário e o depositou em sua conta bancária. Esse trabalhador emitiu dois cheques e agora deseja saber seu saldo atual. O banco criou uma taxa para a operação bancária de retirada que tem que pagar um imposto de 0.38% e o saldo inicial da conta está zerado.
#
#       LEIA salario
#       LEIA valor_cheque1
#       LEIA valor_cheque2
#       imposto_cheque1 = valor_cheque1 * 0.38 / 100
#       saque1 = valor_cheque1 + imposto_cheque1
#       imposto_cheque2 = valor_cheque2 * 0.38 / 100
#       saque2 = valor_cheque2 + imposto_cheque2
#       saldo = salario - saque1 - saque2
#       ESCREVA saldo

# %%
salario = float(input('Digite o valor do salário: '))
valor_cheque1 = float(input('Digite o valor do seu primeiro cheque: '))
valor_cheque2 = float(input('Digite o valor do seu segund cheque: '))
imposto_cheque1 = valor_cheque1 * 0.38 / 100
saque1 = valor_cheque1 + imposto_cheque1
imposto_cheque2 = valor_cheque2 * 0.38 / 100
saque2 = valor_cheque2 + imposto_cheque2
saldo = salario - saque1 - saque2
print('O seu saldo é:',saldo)
# Out:
# Digite o valor do salário: 1212
# Digite o valor do seu primeiro cheque: 300
# Digite o valor do seu segund cheque: 400
# O seu saldo é: 509.34000000000003

# %% [markdown]
# ### 18. Faça um programa que receba a medida do ângulo (em graus) formado por uma escada apoiada no chão e encostada na parede e a altura da parede onde está a ponta da escada. Calcule e mostre a medida dessa escada. Observação: as funções trigonométricas implementadas nas linguagens de programação trabalham com medidas de ângulos em radianos.
#       LEIA angulo
#       LEIA altura
#       import math # carrega a biblioteca matemática
#       radiano = angulo * math.pi / 180
#       escada = altura / math.sin(radiano)
#       ESCREVA escada
# **Observação**: Para usar seno em Python, deve-se usar esta linha de código **import math** e esta, no cálculo, **math.sin(numero)**
#
# **import math**
#
# escada = altura / **math.sin**(numero)

# %%
import math
angulo = float(input('Informe o ângulo: '))
altura_parede = float(input('Informe a altura: '))
radiano = angulo * math.pi / 180
escada = altura_parede / math.sin(radiano)
print(f'A meida da escada é: {escada:.2f}')
# Out:
# Informe o ângulo: 15
# Informe a altura: 3
# A meida da escada é: 11.59

# %% [markdown]
# ###19. Sabe-se que o quilowatt de energia custa um quinto do salário mínimo. Faça um programa que receba o valor do salário mínimo e a quantidade de quilowatts consumida por uma residência. Calcule e mostre:
#
#
# * o valor de cada quilowatt;
# * o valor a ser pago por essa residência;
# * o valor a ser pago com desconto de 15%.
#       LEIA valor_salario
#       LEIA qtde_quilowatt
#       valor_quilowatt = valor_salario / 5
#       valor_em_reais = valor_quilowatt * qtde_quilowatt
#       valor_descontado = valor_em_reais * 15 / 100
#       valor_com_desconto =  valor_em_reais − valor_descontado
#       ESCREVA valor_quilowatt
#       ESCREVA valor_em_reais
#       ESCREVA valor_com_desconto

# %%
valor_salario = float(input('Informe o valro do salário: '))
qtde_quilowatt = float(input('Informe a quantidade de quilowatts consumida: '))
valor_quilowatt = valor_salario / 5
valor_em_reais = valor_quilowatt * qtde_quilowatt
valor_descontado = valor_em_reais * 15 / 100
valor_com_desconto = valor_em_reais - valor_descontado
print('O valor do quilowatt é:',valor_quilowatt)
print('O valor em R$ é:',valor_em_reais)
print('O valor com desconto é:',valor_com_desconto)
# Out:
# Informe o valro do salário: 1212
# Informe a quantidade de quilowatts consumida: 5
# O valor do quilowatt é: 242.4
# O valor em R$ é: 1212.0
# O valor com desconto é: 1030.2

# %% [markdown]
# ### 20. Faça um programa que receba um número real, encontre e mostre:
#
# * a parte inteira desse número;
# * a parte fracionária desse número;
# * o arredondamento desse número.
#
#       LEIA numero
#       parte_inteira = numero // 1
#       parte_fracionaria = numero - parte_inteira
#       numero_arredondado = round (numero)
#       ESCREVA parte_inteira
#       ESCREVA parte_fracionaria
#       ESCREVA numero_arredondado
#
# **Observação**: Para arredondar um número em Python, usa-se a função **round(numero)**, onde se o número real/float estiver em igual distância entre o inteiro de cima e o inteiro de baixo, esta função arredonda para o número mais próximo.

# %%
numero = float(input('Digite o seu número: '))
parte_inteira = numero // 1
parte_fracionaria = numero - parte_inteira
numero_arredondado = round (numero)
print('A parte inteira do número é:',parte_inteira)
print('A parte fracionária do número é:',parte_fracionaria)
print('O número arredondado é:',numero_arredondado)
# Out:
# Digite o seu número: 3.5
# A parte inteira do número é: 3.0
# A parte fracionária do número é: 0.5
# O número arredondado é: 4

# %% [markdown]
# ### 21. Faça um programa que receba uma hora formada por hora e minutos (um número real), calcule e mostre a hora digitada apenas em minutos. Lembre-se de que:
# * para quatro e meia, deve-se digitar 4.30;
# * os minutos vão de 0 a 59.
#       LEIA hora
#       h = pegar a parte inteira da variável hora
#       minutos = hora − h
#       conversao = (h * 60) + (minutos * 100)
#       ESCREVA conversao

# %%
hora = float(input('Informe a hora'))
h = hora // 1
minutos = hora - h
conversao = (h * 60) + (minutos * 100)
print('Os minutos são', conversao)
print(f'Minutos com formatação {conversao:.2f}')
# Out:
# Informe a hora4.35
# Os minutos são 274.99999999999994
# Minutos com formatação 275.00

# %% [markdown]
# ### 22. Faça um programa que receba o custo de um espetáculo teatral e o preço do convite desse espetáculo. Esse programa deverá calcular e mostrar a quantidade de convites que devem ser vendidos para que, pelo menos, o custo do espetáculo seja alcançado.

# %%
custo_espetaculo = float(input('Digite o custo para realizar o espetáculo: '))
convite = float(input('Digite o valor do convite: '))
qtde_convite = custo_espetaculo / convite 
print('A quantidade de convites necessário para pague o espetáculo é:',qtde_convite)
# Out:
# Digite o custo para realizar o espetáculo: 10000
# Digite o valor do convite: 50
# A quantidade de convites necessário para pague o espetáculo é: 200.0
