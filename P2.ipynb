# %% [markdown]
# ##**P2 - 2º. semestre/2022 - Término:22:30**
# ## É uma prova de consulta ao seu material.
# ## **Apenas verificarei** o desenvolvimento dos exercícios de cada aluno, **NO DIA SEGUINTE**
# ##**O exame P3**, ocorrerá **dia 05/12** no **horário normal de aula**. Se puderem podem chegar um pouco antes.
# ##O aluno tem que ter **12 pontos** na soma da P1 com a P2 para ser aprovado.
#
# ##Até dia 04/12 a nota estará registrada no SIGA.
# ##A partir da próxima semana não conta mais presenças, mas o aluno se quiser ver a correção da prova, ou tirar dúvidas, pode vir a aula.
#
# ##**Sempre leiam** seus e-mails do @fatec.sp.gov.br e o Teams, pois é o nosso meio de comunicação com os alunos. **Fiquem atentos a data de rematrícula**, a secretaria informará.
#
# #**Feliz Natal e um próspero Ano Novo, cheio de saúde e bençãos a todos vocês!!**
# #**Boas férias!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!**

# %% [markdown]
# ###**1.** [1,50 pontos] Em Python, crie um programa que leia a quantidade de linhas e colunas de uma matriz.
# ###Digite valores da matriz utilizando o tipo de dado int.
# ###Verifique e apresente se ela "é simétrica" ou "não é simétrica". Uma matriz é considerada simétrica quando a quantidade de linhas é igual a quantidade de colunas.
# ###Mostre a matriz no formato de linha e colunas, conforme foi visto em aula.

# %%
numeros = []
linhass = int(input('Digite a quantidade de linhas'))
colunas = int(input('Digite a quantidade de linhas'))

for linha in range (linhass):
    vet_linha = []
    for coluna in range (colunas):
        vet_linha.append(int(input(f'Digite o valor [{linha}][{coluna}]:')))
    numeros.append(vet_linha)
print('\nApresentado a matriz de forma simples')
print(numeros)
print('\nApresentado a matriz de forma tabular')
for linha in range(len(numeros)):
    for coluna in range(len(numeros[0])):
        print(numeros[linha][coluna], end = '\t')

for linha in range(len(numeros)):
    for coluna in range(len(numeros[0])):
        print(f'Elemento: {numeros[linha][coluna]}\tÍndice da linha: {linha} \tÍndice da coluna: {coluna}')

# %% [markdown]
# ###**2.** [5,50 pontos] Foi realizada uma pesquisa sobre algumas características físicas de ALGUNS habitantes de uma região, NÃO FOI INFORMADA A QUANTIDADE TOTAL, então use como critério de parada, idade igual a zero para encerrar a repetição. Preste atenção nesse detalhe, pois **somente poderá usar a função *append*, quando for digitado uma idade válida**.
#
# ###Foram coletados os seguintes dados de cada habitante: idade, gênero (M/F), cor dos olhos (A - azuis ou C - castanhos). Escolha se quer armazenar uma letra ou a palavra, para cor dos olhos.
#
# ###Em Python crie um programa que leia esses dados, armazenando-os em vetores, uma para idade, outro para gênero (apenas uma letra) e outro para cor dos olhos.
#
# ###Calcule e apresente:
#
# * Média de idades das pessoas com olhos castanhos;
#
# * Quantidade de pessoas que foram entrevistadas
#
# * Quantidade de pessoas do gênero feminino com idade entre 18 e 35 anos e que tenham olhos azuis.
#
# ###**Observação**: pode usar o operador ***in*** e a função ***len***()e a ***append***() apenas. Outras funções prontas da linguagem Python, não serão aceitas.

# %%
pessoas = int(input('Para cadastrar um novo participante digite 1, e para encerrar digite 0: '))
idade = []
genero = []
olhos = []
qtde_pessoas = 0
qtde_18_35 = 0
soma = 0
qtde_castanhos = 0

while pessoas > 0:
    for i in range(pessoas):
        idade.append(int(input('Digite a idade : ')))
    
    for i in range(pessoas):
        genero.append(input('Digite seu genero M/m ou F/f : '))
    for i in range(pessoas):
        olhos.append(input('Digite a cor dos olhos: '))
        if olhos [i] == 'c' or olhos [i] == 'C':
            soma = soma + idade [i]
            qtde_castanhos += 1
        if olhos [i] == "a" or olhos [i] == "A" and genero[i] == "f" or genero [i] == "F" and idade [i] >= 18 and idade [i] <= 35:
            qtde_18_35 += 1
    qtde_pessoas += 1

    pessoas = int(input('Para encerrar digite zero, e para continuar digite 1: '))

media = soma / qtde_castanhos
print('A média de idades das pessoas com olho castanho é: ',media)
print('A quantidade de pessoas entrevistadas foram: ',qtde_pessoas)
print('A quantidade de pessoas do genero feminino que tem entre 18 e 35 anos que tem olho azul são: ',qtde_18_35)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-ddd185a1201f> in <module>
# ----> 1 pessoas = int(input('Para cadastrar um novo participante digite 1, e para encerrar digite 0: '))
#       2 idade = []
#       3 genero = []
#       4 olhos = []
#       5 qtde_pessoas = 0
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
# ...
