# %% [markdown]
# #ESTRUTURA DE REPETIÇÃO
# ##Todos estes algoritmos/programas podem ser implementados com o comando **while** ou **for**. Para estudar, implemente cada exercício com as **duas** estruturas de repetição.

# %% [markdown]
# ###1. Faça um algoritmo  que mostre 10 vezes a frase “Bem vindo a Fatec!”. Pode implementar com o comando while ou for.

# %%
print('Exemplo do while.............')
#inicialização
contador = 1
#condição/critério de parada
while contador <= 5:
    print(contador,'Bem vindo a Fatec!')
    #incremento
    contador = contador + 1

print('\n\nExemplo do for.............')
for contador in range(5):
    print(contador,'Bem vindo a Fatec!')
# Out:
# Exemplo do while.............
# 1 Bem vindo a Fatec!
# 2 Bem vindo a Fatec!
# 3 Bem vindo a Fatec!
# 4 Bem vindo a Fatec!
# 5 Bem vindo a Fatec!
#
#
# Exemplo do for.............
# 0 Bem vindo a Fatec!
# 1 Bem vindo a Fatec!
# 2 Bem vindo a Fatec!
# 3 Bem vindo a Fatec!
# 4 Bem vindo a Fatec!

# %% [markdown]
# ###2. Faça um algoritmo que mostre o cumprimento ‘Olá ‘ para o nome de alguém (4 pessoas). Exemplo ‘Olá Mariana’. Pode implementar com o comando while ou for.

# %%
cont = 1
while cont <= 4:
    nome = input('Digite o nome da pessoa: ')
    print('Olá',nome)
    cont += 1
# Out:
# Digite o nome da pessoa: oi
# Olá oi
# Digite o nome da pessoa: eae
# Olá eae
# Digite o nome da pessoa: salve
# Olá salve
# Digite o nome da pessoa: fala fei
# Olá fala fei

# %% [markdown]
# ###3. Faça um algoritmo que mostre os valores de 0 a 15. Pode implementar com o comando while ou for.

# %%
val = 0
while val <= 15:
    print('Número',val)
    val += 1
# Out:
# Número 0
# Número 1
# Número 2
# Número 3
# Número 4
# Número 5
# Número 6
# Número 7
# Número 8
# Número 9
# Número 10
# Número 11
# Número 12
# Número 13
# Número 14
# Número 15

# %% [markdown]
# ###4. Faça um algoritmo que mostre os valores de 3 a 20. Pode implementar com o comando while ou for.

# %%
val = 3
while val <= 20:
    print('Número',val)
    val +=1
# Out:
# Número 3
# Número 4
# Número 5
# Número 6
# Número 7
# Número 8
# Número 9
# Número 10
# Número 11
# Número 12
# Número 13
# Número 14
# Número 15
# Número 16
# Número 17
# Número 18
# Número 19
# Número 20

# %% [markdown]
# ###5. Faça um algoritmo que calcule e mostre a tabuada do 5. Pode implementar com o comando while ou for.

# %%
tab = 5
mul = 0
print('Tabuada do 5')
while tab <= 50:
    tab += 5
    while mul <=10:
        mul +=1
        print(mul'x'5'='tab)
# Out:
#   File "<ipython-input-7-971cd91d3d1c>", line 8
#     print(mul'x'5'='tab)
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###6. Faça um algoritmo que receba a idade de 10 pessoas, calcule e exiba a quantidade de pessoas maiores de idade, sendo que a maioridade é obtida após completar 18 anos. Pode implementar com o comando while ou for.

# %%
pessoas = 0
maior_18 = 0

while pessoas < 10:
    idade = int(input('Digite a idade: '))
    if idade >=18:
        maior_18 += 1
    pessoas += 1
print('Foram encontradas',maior_18,'pessoas maior de 18')
# Out:
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Digite a idade: 20
# Foram encontradas 10 pessoas maior de 18

# %%
maior_18 = 0
for pessoas in range (10):
    idade = int(input('Digite a idade: '))
    if idade >= 18:
        maior_18 += 1
print('Foram encontradas',maior_18,'pessoas maior de 18')
# Out:
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Digite a idade: 2
# Foram encontradas 0 pessoas maior de 18

# %% [markdown]
# ###7. Escreva um algoritmo que receba 23 números, calcule e exiba a quantidade de números pares e impares. Pode implementar com o comando while ou for.

# %%
contador = 0
pares = 0
impares = 0
while contador < 23:
    num= int(input('Digite um número: '))
    if num % 2 == 0:
      pares +=1  
    else:
        impares +=1
    contador += 1
print('A quantidade de pares é',pares,'e a quantidade de impares é',impares)
# Out:
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# Digite um número: 2
# A quantidade de pares é 23 e a quantidade de impares é 0

# %% [markdown]
# ###8. Faça um algoritmo que calcule e exiba o salário reajustado de dez funcionários de acordo com a seguinte regra (pode implementar com o comando while ou for):
# ## Salário até 300, reajuste de 50%;
#
# ##Salários maiores que 300, reajuste de 30%.

# %%
funcionarios = 0
while funcionarios < 3:
    salario = float(input('Digite o valor do salário:'))
    if salario <= 300:
        reajuste = salario * (50/100) + salario
        print('O salário reajustado é', reajuste)
    else:
        reajuste = salario * (30/100) + salario
        print('O salário reajustado é', reajuste)
    funcionarios += 1
# Out:
# Digite o valor do salário:2000
# O salário reajustado é 2600.0
# Digite o valor do salário:200
# O salário reajustado é 300.0
# Digite o valor do salário:4000
# O salário reajustado é 5200.0

# %% [markdown]
# ###9. Faça um algoritmo que conheça 4 preços de produtos, some-os e mostre o resultado. Pode implementar com o comando while ou for.

# %%
contador = 0
produto = 0 
while contador < 4:
    valor = float(input('Digite o preco do produto: '))
    produto = produto + valor
    contador += 1
print ('A soma dos precos informados é igual a ', produto)
# Out:
# Digite o preco do produto: 30
# Digite o preco do produto: 30
# Digite o preco do produto: 30
# Digite o preco do produto: 30
# A soma dos precos informados é igual a  120.0

# %% [markdown]
# ###10. Faça um algoritmo que calcule e informe a média de idades de 5 alunos. Pode implementar com o comando while ou for.

# %%
contador = 0
soma_idade = 0
while contador < 5:
    idade = int(input('Digite a idade: '))
    soma_idade = soma_idade = idade
    contador += 1
print(soma_idade)
media = soma_idade / contador
print(f'A média é {media:.2f}')
# Out:
# Digite a idade: 10
# Digite a idade: 10
# Digite a idade: 10
# Digite a idade: 10
# Digite a idade: 10
# 10
# A média é 2.00

# %% [markdown]
# ###11. Faça um algoritmo que conheça 4 preços de produtos, calcule e mostre a média aritmética dos preços. Pode implementar com o comando while ou for.

# %%
contador = 0
produto = 0 
while contador < 4:
    valor = float(input('Digite o preco do produto: '))
    produto = produto + valor
    contador += 1
print ('A soma dos precos informados é igual a ', produto)
media = produto / 4
print(f'E a média aritmética dos precos é de {media: .2f}')
# Out:
# Digite o preco do produto: 30
# Digite o preco do produto: 30
# Digite o preco do produto: 30
# Digite o preco do produto: 30
# A soma dos precos informados é igual a  120.0
# E a média aritmética dos precos é de  30.00

# %% [markdown]
# ###12. Faça um programa que receba a idade e a altura de 20 pessoas. Calcule e exiba a média das alturas das pessoas com mais de 20 anos.

# %%
pessoas = 0
soma_altura = 0
maior_de_20 = 0
while pessoas < 3:
    idade = int(input('Digite sua idade'))
    altura = float(input('Digite sua altura'))
    if idade > 20:
        soma_altura = soma_altura + altura
        maior_de_20 += 1
    pessoas += 1
print('A quantidade de pessoas maiores de 20 anos sao',maior_de_20)

media_altura = soma_altura / maior_de_20

print(f'E a média aritmética da altura é de {media_altura: .2f}')
# Out:
# Digite sua idade15
# Digite sua altura1.90
# Digite sua idade21
# Digite sua altura1.92
# Digite sua idade30
# Digite sua altura1.70
# A quantidade de pessoas maiores de 20 anos sao 2
# E a média aritmética dos precos é de  1.81

# %% [markdown]
# ###13. Faça um algoritmo que leia o preço de 20 TV, determine e apresente a média dos preços que possuem valor maior que R$ 1000. Pode implementar com o comando while ou for.

# %%
tv = 0 
soma_preco = 0 
maior_de_1000 = 0
while tv < 3:
    print('Tv',tv)
    preco = float(input('Digite o preco: '))
    
    if preco > 1000:
        soma_preco = soma_preco + preco
        maior_de_1000 += 1
    tv += 1
print('A quantidade de tv com preco superior a 1000 reais é',maior_de_1000)

media_preco = soma_preco / maior_de_1000
print(f'E a média dos precos será {media_preco: .2f}')
# Out:
# Tv 0
# Digite o preco: 1300
# Tv 1
# Digite o preco: 1300
# Tv 2
# Digite o preco: 1300
# A quantidade de tv com preco superior a 1000 reais é 3
# E a média dos precos será  1300.00

# %% [markdown]
# ###14. Faça um programa que calcule e apresente as tabuadas do 3 ao 7. Este exercício utiliza DUAS estruturas de repetição.

# %%
for intervalo in range (3,8):
    for tabuada in range(1,11):
        print(intervalo,'x', tabuada,'=', tabuada * intervalo)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# ###15. Faça um programa para o curso de ADS (6 módulos), cada sala tem 30 alunos, calcule e apresente os seguintes itens:
# *  Quantidade de homens e mulheres de cada módulo;
# *  Média de idades de cada módulo;
# *  Quantidade de homens e mulheres do curso todo;
# *  Média de idades do curso todo.
#
# Observação: este exercício utiliza DUAS estruturas de repetição.

# %%
modulo = 1
while modulo <= 6:
    contador = 1
    homem = 0
    mulher = 0
    idadeM = 0
    idadeH = 0
    while contador <=30:
        sexo = str (input('Informe o sexo H ou M: '))
        idade = float(input('Informe a idade: '))
        if sexo == "M":
            mulher += 1
            idadeM = idade + idadeM
        if sexo =="H":
            homem += 1
            idadeH = idade + idadeH
            contador += 1
    media_idade_mulher = idadeM / mulher
    media_idade_homem = idadeH / homem

    print(modulo ,'modulo', '.' *50)
    print('totais de homens', homem)
    print('media de idade de homens', media_idade_homem)
    print('totais de homens', mulher)
    print('media de idade de mulheres', media_idade_mulher)
    modulo += 1
# Out:
# Informe o sexo H ou M: H
# Informe a idade: 20
# Informe o sexo H ou M: M
# Informe a idade: 20
# Informe o sexo H ou M: M
# Informe a idade: 30
# Informe o sexo H ou M: H
# Informe a idade: 35
# Informe o sexo H ou M: M
# Informe a idade: 27
# Informe o sexo H ou M: H
# Informe a idade: 30
# 1 modulo ..................................................
# totais de homens 3
# media de idade de homens 28.333333333333332
# totais de homens 3
# media de idade de homens 25.666666666666668
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-eb24446f0e74> in <module>
#       7     idadeH = 0
#       8     while contador <=3:
# ----> 9         sexo = str (input('Informe o sexo H ou M: '))
#      10         idade = float(input('Informe a idade: '))
#      11         if sexo == "M":
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
